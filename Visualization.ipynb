# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [-3, 5, 7]
y = [10, 2, 5]

# %%
plt.figure(figsize=(15,3))

# %%
# Draw a graph using the 'stateful' (non-object-oriented) interface
plt.plot(x, y)
plt.xlim(0, 10)
plt.ylim(-3, 8)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Plot')
plt.suptitle('Figure Title', size=20, y=1.03)
# Out:
# Text(0.5,1.03,'Figure Title')

# %%
# Draw a graph using the object-oriented interface
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15,3))
ax.plot(x,y)
ax.set_xlim(0, 10)
ax.set_ylim(-3, 8)
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_title('Line Plot')
fig.suptitle('Figure Title', size=20, y=1.03)
# Out:
# Text(0.5,1.03,'Figure Title')

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
fig.get_size_inches()
# Out:
# array([15.,  3.])

# %%
fig.set_size_inches(14, 4)
fig

# %%
fig.axes

# %%
fig.axes[0] is ax
# Out:
# True

# %%
fig.set_facecolor('.9')
ax.set_facecolor('.7')
fig

# %%
ax_children = ax.get_children()
ax_children
# Out:
# [<matplotlib.lines.Line2D at 0x11c2816a0>,
#  <matplotlib.spines.Spine at 0x11c28d588>,
#  <matplotlib.spines.Spine at 0x11c28d860>,
#  <matplotlib.spines.Spine at 0x11c28d198>,
#  <matplotlib.spines.Spine at 0x11c28d710>,
#  <matplotlib.axis.XAxis at 0x11c28db00>,
#  <matplotlib.axis.YAxis at 0x11c28de48>,
#  Text(0.5,1,'Line Plot'),
#  Text(0,1,''),
#  Text(1,1,''),
#  <matplotlib.patches.Rectangle at 0x11c2a00b8>]

# %%
spines = ax.spines
spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x11c28d588>),
#              ('right', <matplotlib.spines.Spine at 0x11c28d860>),
#              ('bottom', <matplotlib.spines.Spine at 0x11c28d198>),
#              ('top', <matplotlib.spines.Spine at 0x11c28d710>)])

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -100))
spine_left.set_linewidth(5)
spine_bottom = spines['bottom']
spine_bottom.set_visible(False)
fig

# %%
ax.xaxis.grid(True, which='major', linewidth=2, color='black', linestyle='--')
ax.xaxis.set_ticks([2, 4, 5.5, 9.3])
ax.xaxis.set_label_text('X Axis', family='Verdana', fontsize=15)
ax.set_ylabel('Y Axis', family='Ubuntu', fontsize=20)
ax.set_yticks([.1, .9])
ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
ax.set_animated(False)
fig

# %%
plot_objects = plt.subplots(nrows=1, ncols=1)
type(plot_objects)
# Out:
# tuple

# %%
fig = plot_objects[0]
ax = plot_objects[1]
fig, ax
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11c436ba8>)

# %%
plot_objects = plt.subplots(2, 4)

# %%
plot_objects[1]
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c307668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c270dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bdc9da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd73a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bcbcef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bbf3ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1eb080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c17e710>]],
#       dtype=object)

# %%
ax.xaxis.properties()
# Out:
# {'agg_filter': None,
#  'alpha': None,
#  'animated': False,
#  'children': [Text(0.5,3.2,''),
#   Text(1,4.2,''),
#   <matplotlib.axis.XTick at 0x11ce957b8>,
#   <matplotlib.axis.XTick at 0x11ce950f0>,
#   <matplotlib.axis.XTick at 0x11cea74a8>,
#   <matplotlib.axis.XTick at 0x11cea77b8>,
#   <matplotlib.axis.XTick at 0x11cea7eb8>,
#   <matplotlib.axis.XTick at 0x11d1b73c8>],
#  'clip_box': <matplotlib.transforms.TransformedBbox at 0x11ce83fd0>,
#  'clip_on': True,
#  'clip_path': None,
#  'contains': None,
#  'data_interval': array([ inf, -inf]),
#  'figure': <Figure size 432x288 with 1 Axes>,
#  'gid': None,
#  'gridlines': <a list of 6 Line2D gridline objects>,
#  'label': Text(0.5,3.2,''),
#  'label_position': 'bottom',
#  'label_text': '',
#  'major_formatter': <matplotlib.ticker.ScalarFormatter at 0x11c326080>,
#  'major_locator': <matplotlib.ticker.AutoLocator at 0x11ce86e10>,
#  'major_ticks': [<matplotlib.axis.XTick at 0x11ce957b8>,
#   <matplotlib.axis.XTick at 0x11ce950f0>,
#   <matplotlib.axis.XTick at 0x11cea74a8>,
#   <matplotlib.axis.XTick at 0x11cea77b8>,
#   <matplotlib.axis.XTick at 0x11cea7eb8>,
#   <matplotlib.axis.XTick at 0x11d1b73c8>],
#  'majorticklabels': <a list of 6 Text major ticklabel objects>,
#  'majorticklines': <a list of 12 Line2D ticklines objects>,
#  'majorticklocs': array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  'minor_formatter': <matplotlib.ticker.NullFormatter at 0x11ce86f98>,
#  'minor_locator': <matplotlib.ticker.NullLocator at 0x11c326fd0>,
#  'minor_ticks': [],
#  'minorticklabels': <a list of 0 Text minor ticklabel objects>,
#  'minorticklines': <a list of 0 Line2D ticklines objects>,
#  'minorticklocs': [],
#  'minpos': inf,
#  'offset_text': Text(1,4.2,''),
#  'path_effects': [],
#  'picker': None,
#  'pickradius': 15,
#  'rasterized': None,
#  'scale': 'linear',
#  'sketch_params': None,
#  'smart_bounds': False,
#  'snap': None,
#  'tick_padding': 3.5,
#  'tick_space': 11,
#  'ticklabels': <a list of 6 Text major ticklabel objects>,
#  'ticklines': <a list of 12 Line2D ticklines objects>,
#  'ticklocs': array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  'ticks_direction': array(['out', 'out', 'out', 'out', 'out', 'out'], dtype='<U3'),
#  'ticks_position': 'bottom',
#  'transform': <matplotlib.transforms.IdentityTransform at 0x11bc976a0>,
#  'transformed_clip_path_and_affine': (None, None),
#  'units': None,
#  'url': None,
#  'view_interval': array([0., 1.]),
#  'visible': True,
#  'zorder': 1.5}

# %%
movie = pd.read_csv('data/movie.csv')
med_budget = movie.groupby('title_year')['budget'].median() / 6

# %%
med_budget_roll = med_budget.rolling(5, min_periods=1).mean()
med_budget_roll.tail()
# Out:
# title_year
# 2012.0    3.482167e+06
# 2013.0    3.315500e+06
# 2014.0    3.183333e+06
# 2015.0    2.996667e+06
# 2016.0    2.963333e+06
# Name: budget, dtype: float64

# %%
years = med_budget_roll.index.values
years[-5:]
# Out:
# array([2012., 2013., 2014., 2015., 2016.])

# %%
budget = med_budget_roll.values
budget[-5:]
# Out:
# array([3482166.66666667, 3315500.        , 3183333.33333333,
#        2996666.66666667, 2963333.33333333])

# %%
fig, ax = plt.subplots(figsize=(14,4), linewidth=5, edgecolor='.5')

# %%
ax.plot(years, budget, linestyle='--', linewidth=3, color='.2', label='All Movies')

# %%
text_kwargs=dict(fontsize=20, family='cursive')
ax.set_title('Median Movie Budget', **text_kwargs)
ax.set_ylabel('Millions of Dollars', **text_kwargs)
fig

# %%
movie_count = movie.groupby('title_year')['budget'].count()
movie_count.tail()
# Out:
# title_year
# 2012.0    191
# 2013.0    208
# 2014.0    221
# 2015.0    192
# 2016.0     86
# Name: budget, dtype: int64
